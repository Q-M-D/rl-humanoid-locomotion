# %%
import numpy as np
import os
from rich import print as rprint

# %%
data = np.load('./test_data.npz', allow_pickle=True)

# %%
print(data['obs'].shape)
print(data['critic_obs'].shape)
print(data['actions'].shape)
print(data['rewards'].shape)
print(data['dones'].shape)
print(data['infos'].shape)
# Out:
# (1200, 1, 940)
# (1200, 1, 219)
# (1200, 1, 12)
# (1200, 1)
# (1200,)
# (1200,)
